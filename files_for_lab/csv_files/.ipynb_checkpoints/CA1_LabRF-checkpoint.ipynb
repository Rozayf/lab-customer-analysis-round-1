# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')
display(file1.head(10))

file2 = pd.read_csv('file2.csv')
display(file2.head(10))

file3 = pd.read_csv('file3.csv')
display(file3.head(10))
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
# 6  XZ87318      Oregon      F               College              538089.86%
# 7  CF85061     Arizona      M                Master              721610.03%
# 8  DY87989      Oregon      M              Bachelor             2412750.40%
# 9  BQ94931      Oregon      F               College              738817.81%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
file1.shape
file2.shape
file3.shape
# Out:
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
file1 = file1.rename(columns={'ST':'State',
                            'GENDER':'Gender'})
file1.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file2 = file2.rename(columns={'ST':'State',
                            'GENDER':'Gender'})

# %%
data1 = file1
data1.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
data2 = file2
data2.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
data3 = file3
data3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
data1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data1 = data1 [['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints','Policy Type', 'Total Claim Amount', 'Vehicle Class']]

# %%
data1
# Out:
#      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 4003      NaN         NaN                     NaN                   NaN
# 4004      NaN         NaN                     NaN                   NaN
# 4005      NaN         NaN                     NaN                   NaN
# 4006      NaN         NaN                     NaN                   NaN
# 4007      NaN         NaN                     NaN                   NaN
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
data2 = data2 [['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints','Policy Type', 'Total Claim Amount', 'Vehicle Class']]

# %%
data2
# Out:
#     Customer       State Customer Lifetime Value Education Gender  Income  \
# 0    GS98873     Arizona              323912.47%  Bachelor      F   16061
# 1    CW49887  California              462680.11%    Master      F   79487
# 2    MY31220  California              899704.02%   College      F   54230
# 3    UH35128      Oregon             2580706.30%   College      F   71210
# 4    WH52799     Arizona              380812.21%   College      F   94903
# ..       ...         ...                     ...       ...    ...     ...
# 991  HV85198     Arizona              847141.75%    Master      M   63513
# 992  BS91566     Arizona              543121.91%   College      F   58161
# 993  IL40123      Nevada              568964.41%   College      F   83640
# 994  MY32149  California              368672.38%    Master      F       0
# 995  SA91515  California              399258.39%  Bachelor      M       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
data1.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value       object
# Education                     object
# Gender                        object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
data1['Customer Lifetime Value'] = data1['Customer Lifetime Value'].str.rstrip('%').astype('float') / 100.0

# %%
data1
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     RB50392  Washington                      NaN                Master
# 1     QZ44356     Arizona                6979.5359              Bachelor
# 2     AI49188      Nevada               12887.4317              Bachelor
# 3     WW63253  California                7645.8618              Bachelor
# 4     GA49547  Washington                5363.0765  High School or Below
# ...       ...         ...                      ...                   ...
# 4003      NaN         NaN                      NaN                   NaN
# 4004      NaN         NaN                      NaN                   NaN
# 4005      NaN         NaN                      NaN                   NaN
# 4006      NaN         NaN                      NaN                   NaN
# 4007      NaN         NaN                      NaN                   NaN
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
data2['Customer Lifetime Value'] = data2['Customer Lifetime Value'].str.rstrip('%').astype('float') / 100.0

# %%
data2
# Out:
#     Customer       State  Customer Lifetime Value Education Gender  Income  \
# 0    GS98873     Arizona                3239.1247  Bachelor      F   16061
# 1    CW49887  California                4626.8011    Master      F   79487
# 2    MY31220  California                8997.0402   College      F   54230
# 3    UH35128      Oregon               25807.0630   College      F   71210
# 4    WH52799     Arizona                3808.1221   College      F   94903
# ..       ...         ...                      ...       ...    ...     ...
# 991  HV85198     Arizona                8471.4175    Master      M   63513
# 992  BS91566     Arizona                5431.2191   College      F   58161
# 993  IL40123      Nevada                5689.6441   College      F   83640
# 994  MY32149  California                3686.7238    Master      F       0
# 995  SA91515  California                3992.5839  Bachelor      M       0
#
# ...

# %%
data_frame = pd.concat([data1, data2, data3], axis=0)

# %%
data_frame
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     RB50392  Washington                      NaN                Master
# 1     QZ44356     Arizona              6979.535900              Bachelor
# 2     AI49188      Nevada             12887.431700              Bachelor
# 3     WW63253  California              7645.861800              Bachelor
# 4     GA49547  Washington              5363.076500  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
data_frame.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
data_frame._get_numeric_data()
# Out:
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# 3                 7645.861800      0.0                 106.0
# 4                 5363.076500  36357.0                  68.0
# ...                       ...      ...                   ...
# 7065             23405.987980  71941.0                  73.0
# 7066              3096.511217  21604.0                  79.0
# 7067              8163.890428      0.0                  85.0
# 7068              7524.442436  21941.0                  96.0
# 7069              2611.836866      0.0                  77.0
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# ...

# %%
data_frame.select_dtypes('object')
# Out:
#      Customer       State             Education Gender  \
# 0     RB50392  Washington                Master    NaN
# 1     QZ44356     Arizona              Bachelor      F
# 2     AI49188      Nevada              Bachelor      F
# 3     WW63253  California              Bachelor      M
# 4     GA49547  Washington  High School or Below      M
# ...       ...         ...                   ...    ...
# 7065  LA72316  California              Bachelor      M
# 7066  PK87824  California               College      F
# 7067  TD14365  California              Bachelor      M
# 7068  UP19263  California               College      M
# 7069  Y167826  California               College      M
#
#      Number of Open Complaints     Policy Type  Vehicle Class
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# ...

# %%
data_frame = data_frame.drop(['Education','Number of Open Complaints'], axis=1)

# %%
data_frame
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 0     RB50392  Washington                      NaN    NaN      0.0
# 1     QZ44356     Arizona              6979.535900      F      0.0
# 2     AI49188      Nevada             12887.431700      F  48767.0
# 3     WW63253  California              7645.861800      M      0.0
# 4     GA49547  Washington              5363.076500      M  36357.0
# ...       ...         ...                      ...    ...      ...
# 7065  LA72316  California             23405.987980      M  71941.0
# 7066  PK87824  California              3096.511217      F  21604.0
# 7067  TD14365  California              8163.890428      M      0.0
# 7068  UP19263  California              7524.442436      M  21941.0
# 7069  Y167826  California              2611.836866      M      0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
data_frame.drop_duplicates()
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 0     RB50392  Washington                      NaN    NaN      0.0
# 1     QZ44356     Arizona              6979.535900      F      0.0
# 2     AI49188      Nevada             12887.431700      F  48767.0
# 3     WW63253  California              7645.861800      M      0.0
# 4     GA49547  Washington              5363.076500      M  36357.0
# ...       ...         ...                      ...    ...      ...
# 7065  LA72316  California             23405.987980      M  71941.0
# 7066  PK87824  California              3096.511217      F  21604.0
# 7067  TD14365  California              8163.890428      M      0.0
# 7068  UP19263  California              7524.442436      M  21941.0
# 7069  Y167826  California              2611.836866      M      0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
filtered_income = data_frame[data_frame['Income']>0.0]

# %%
filtered_income
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 2     AI49188      Nevada             12887.431700      F  48767.0
# 4     GA49547  Washington              5363.076500      M  36357.0
# 5     OC83172      Oregon              8256.297800      F  62902.0
# 6     XZ87318      Oregon              5380.898600      F  55350.0
# 8     DY87989      Oregon             24127.504000      M  14072.0
# ...       ...         ...                      ...    ...      ...
# 7063  TF56202  California              5032.165498      M  66367.0
# 7064  YM19146  California              4100.398533      F  47761.0
# 7065  LA72316  California             23405.987980      M  71941.0
# 7066  PK87824  California              3096.511217      F  21604.0
# 7068  UP19263  California              7524.442436      M  21941.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 2                    108.0   Personal Auto          566.472247   Two-Door Car
# ...
